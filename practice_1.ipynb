# %%
import numpy as np
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/YoungjinBD/dataset/main/airquality.csv')

# df.info()

df_ozone = df['Ozone'].fillna(0)
df_ozone_remove = df['Ozone'].dropna()

print(df_ozone_remove.mean() - df_ozone.mean())

from sklearn.preprocessing import MinMaxScaler, StandardScaler
mm_scaler = MinMaxScaler()

df['Wind_mm'] = mm_scaler.fit_transform(df[['Wind']])

ss_scaler = StandardScaler()
df['Wind_ss'] = ss_scaler.fit_transform(df[['Wind']])

print(df['Wind_mm'].mean() - df['Wind_ss'].mean())

print(df.groupby(['Month'])['Temp'].mean())

df.describe()
# Out:
# 10.188133874239352
# 0.4346061231510147
# Month
# 5    65.548387
# 6    79.100000
# 7    83.903226
# 8    83.967742
# 9    76.900000
# Name: Temp, dtype: float64
#             Ozone     Solar.R        Wind        Temp       Month         Day  \
# count  116.000000  146.000000  153.000000  153.000000  153.000000  153.000000
# mean    42.129310  185.931507    9.957516   77.882353    6.993464   15.803922
# std     32.987885   90.058422    3.523001    9.465270    1.416522    8.864520
# min      1.000000    7.000000    1.700000   56.000000    5.000000    1.000000
# 25%     18.000000  115.750000    7.400000   72.000000    6.000000    8.000000
# 50%     31.500000  205.000000    9.700000   79.000000    7.000000   16.000000
# 75%     63.250000  258.750000   11.500000   85.000000    8.000000   23.000000
# max    168.000000  334.000000   20.700000   97.000000    9.000000   31.000000
#
#           Wind_mm       Wind_ss
# count  153.000000  1.530000e+02
# mean     0.434606 -2.322035e-17
# ...

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/YoungjinBD/dataset/main/airquality.csv')

# ttest_1samp

from scipy.stats import ttest_1samp
temp_mean = round(df['Temp'].mean(), 2)

result=  (ttest_1samp(df['Temp'], 77))

print(temp_mean)
print(round(result[0], 2))
print(round(result[1], 4)) # 귀무가설 채택
# Out:
# 77.88
# 1.15
# 0.2507

# %% [markdown]
# ---

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/YoungjinBD/dataset/main/HR-Employee-Attrition.csv')

from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

df['Attrition_en'] = encoder.fit_transform(df['Attrition'])

# print(df['Attrition_en'].value_counts())

# 2번 문제
# 데이터셋의 데이터타입별 칼럼 개수를 계산하고, 범주형 변수 중 유일한 값을 1개만 가지고 있는 칼럼을 찾아내어 그 변수를 데이터에서 제거하시오
cat_feat = df.select_dtypes('object', 'category').columns.values
print(cat_feat)
df_cat = df.copy()

df_cat['Department'].value_counts()

# 3번 문제
# 데이터셋에서 숫자형인 칼럼만 추출하여 새로운 데이터 프레임 생성하고, 각 변수간의 상관계수를 구하고, 0.9인 이상 두 개의 칼럼 찾아내어 그 중 변수하나 제거
num_feat = df.select_dtypes('number').columns.values
df_num = df[num_feat].copy()

df_num.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/YoungjinBD/dataset/main/HR-Employee-Attrition.csv')

# df.info()
# OverTime MaritalStatus

table = pd.crosstab(df['OverTime'], df['MaritalStatus'])
table
print(186 - 487)

from scipy.stats import chi2_contingency

print(chi2_contingency(table))
print(round(0.8167212449486526, 2))
print(round(0.6647391157283247, 4)) # 채택
# Out:
# -301
# Chi2ContingencyResult(statistic=0.8167212449486526, pvalue=0.6647391157283247, dof=2, expected_freq=array([[234.46122449, 482.54557823, 336.99319728],
#        [ 92.53877551, 190.45442177, 133.00680272]]))
# 0.82
# 0.6647
